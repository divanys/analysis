# %%
import pandas as pd
import numpy as np
import seaborn as sb

data = pd.read_csv('./UNdata_Export_20230807_135634988.csv', index_col='Quantity')

# print(data.head(5))
# data_new = data.drop(['Year'])
# print(data_new)
# sb.heatmap(data)

sb.barplot(x=data['Year'].head(5), y=data['Weight (kg)'].head(5)) # вызываем функцию barplot()
# Out:
# <Axes: xlabel='Year', ylabel='Weight (kg)'>
